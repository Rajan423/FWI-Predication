# %%
print("Jupyter is working")
# Out:
# Jupyter is working

# %%
import sys
print(sys.executable)
# Out:
# e:\jupiter_practice\python.exe

# %%
import numpy    
print(numpy.__version__)
# Out:
# 1.26.4

# %%
import pandas 
print(pandas.__version__)
# Out:
# 2.2.2
